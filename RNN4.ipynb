# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import  layers
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
data=['این فیلم افتضاح بود',
      'این فیلم خوب بود',
      'این فیلم خیلی بد بود',
      'این فیلم خیلی عالی بود',
      'یکی از بدترین فیلم هایی که دیدم','چیزی از آن نفهمیدم',
      'این فیلم فوق العاده بود',
      'تجربه خوبی بود ','نبایذ تماشا کرد','بهترین فیلم سال']

# %%
labels=[0,1,0,1,0,0,1,1,0,1]

# %%
tokenizer=keras.preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(data)
sequences=tokenizer.texts_to_sequences(data)
X=pad_sequences(sequences)

# %%
y=np.array(labels)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print(x_train.shape,x_test.shape)
# Out:
# (8, 7) (2, 7)

# %%
model=keras.Sequential([
    layers.Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=64,input_length=X.shape[1]),
    layers.LSTM(64, return_sequences=False),
    layers.Dropout(0.5),
    layers.Dense(1, activation="sigmoid")
    ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(loss='binary_crossentropy',optimizer="adam",metrics=['accuracy'])

# %%
model.fit(x_train, y_train , epochs=50, batch_size=2, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 206ms/step - accuracy: 0.5000 - loss: 0.6949 - val_accuracy: 0.5000 - val_loss: 0.6907
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6333 - loss: 0.6887 - val_accuracy: 0.5000 - val_loss: 0.6903
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.6333 - loss: 0.6881 - val_accuracy: 0.5000 - val_loss: 0.6905
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7833 - loss: 0.6795 - val_accuracy: 0.5000 - val_loss: 0.6906
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8667 - loss: 0.6777 - val_accuracy: 0.5000 - val_loss: 0.6905
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.7833 - loss: 0.6733 - val_accuracy: 0.5000 - val_loss: 0.6904
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8667 - loss: 0.6563 - val_accuracy: 0.5000 - val_loss: 0.6911
# Epoch 8/50
# ...

# %%
loss , accuracy=model.evaluate(x_test, y_test)
print(f"Loss:, {loss}, Accuracy:{accuracy}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - accuracy: 0.5000 - loss: 2.3056
# Loss:, 2.3056349754333496, Accuracy:0.5

# %%
def predict_sentiment(review):
  sequence=tokenizer.texts_to_sequences([review])
  padded_sequence=pad_sequences(sequence, maxlen=X.shape[1])
  prediction=model.predict(padded_sequence)
  return "مثبت" if prediction[0][0] > 0.5 else " منفی"

# %%
sample_review='این فیلم واقعا خوب بود'
predicted_sentiment=predict_sentiment(sample_review)
print(f'پیشبینی احساسات برای توییت  "{sample_review}":{predicted_sentiment}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# پیشبینی احساسات برای توییت  "این فیلم واقعا خوب بود":مثبت
