# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
whc=pd.read_csv('C:\\Users\ASUS\Desktop\World Happiness Report.csv')
whc
# Out:
#                       Country  Happiness Rank  Happiness Score   Economy  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 148                    Rwanda             151            3.471  0.368746
# 149                     Syria             152            3.462  0.777153
# 150                  Tanzania             153            3.349  0.511136
# 151                   Burundi             154            2.905  0.091623
# 152  Central African Republic             155            2.693  0.000000
#
#        Family    Health   Freedom  Generosity  Corruption  Dystopia  \
# ...

# %%
whc.head(10)
# Out:
#        Country  Happiness Rank  Happiness Score   Economy    Family    Health  \
# 0       Norway               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3  Switzerland               4            7.494  1.564980  1.516912  0.858131
# 4      Finland               5            7.469  1.443572  1.540247  0.809158
# 5  Netherlands               6            7.377  1.503945  1.428939  0.810696
# 6       Canada               7            7.316  1.479204  1.481349  0.834558
# 7  New Zealand               8            7.314  1.405706  1.548195  0.816760
# 8       Sweden               9            7.284  1.494387  1.478162  0.830875
# 9    Australia              10            7.284  1.484415  1.510042  0.843887
#
#     Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# ...

# %%
whc.shape
# Out:
# (153, 12)

# %%
print("There are {:,} rows ".format(whc.shape[0]) + "and {} columns in our data".format(whc.shape[1]))
# Out:
# There are 153 rows and 12 columns in our data

# %%
whc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           153 non-null    object
#  1   Happiness Rank    153 non-null    int64
#  2   Happiness Score   153 non-null    float64
#  3   Economy           153 non-null    float64
#  4   Family            153 non-null    float64
#  5   Health            153 non-null    float64
#  6   Freedom           153 non-null    float64
#  7   Generosity        153 non-null    float64
#  8   Corruption        153 non-null    float64
#  9   Dystopia          153 non-null    float64
#  10  Job Satisfaction  151 non-null    float64
#  11  Region            153 non-null    object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.5+ KB

# %%
whc.dtypes
# Out:
# Country              object
# Happiness Rank        int64
# Happiness Score     float64
# Economy             float64
# Family              float64
# Health              float64
# Freedom             float64
# Generosity          float64
# Corruption          float64
# Dystopia            float64
# Job Satisfaction    float64
# Region               object
# dtype: object

# %%
whc.isnull().sum()
# Out:
# Country             0
# Happiness Rank      0
# Happiness Score     0
# Economy             0
# Family              0
# Health              0
# Freedom             0
# Generosity          0
# Corruption          0
# Dystopia            0
# Job Satisfaction    2
# Region              0
# dtype: int64

# %%
whc.drop_duplicates(inplace=True)
whc
# Out:
#                       Country  Happiness Rank  Happiness Score   Economy  \
# 0                      Norway               1            7.537  1.616463
# 1                     Denmark               2            7.522  1.482383
# 2                     Iceland               3            7.504  1.480633
# 3                 Switzerland               4            7.494  1.564980
# 4                     Finland               5            7.469  1.443572
# ..                        ...             ...              ...       ...
# 148                    Rwanda             151            3.471  0.368746
# 149                     Syria             152            3.462  0.777153
# 150                  Tanzania             153            3.349  0.511136
# 151                   Burundi             154            2.905  0.091623
# 152  Central African Republic             155            2.693  0.000000
#
#        Family    Health   Freedom  Generosity  Corruption  Dystopia  \
# ...

# %%
whc.describe()
# Out:
#        Happiness Rank  Happiness Score     Economy      Family      Health  \
# count      153.000000       153.000000  153.000000  153.000000  153.000000
# mean        78.169935         5.349281    0.982433    1.186630    0.550117
# std         45.008741         1.134997    0.421901    0.288441    0.237769
# min          1.000000         2.693000    0.000000    0.000000    0.000000
# 25%         40.000000         4.497000    0.659517    1.041990    0.364509
# 50%         78.000000         5.279000    1.064578    1.251826    0.606042
# 75%        117.000000         6.098000    1.315175    1.416404    0.719217
# max        155.000000         7.537000    1.870766    1.610574    0.949492
#
#           Freedom  Generosity  Corruption    Dystopia  Job Satisfaction
# count  153.000000  153.000000  153.000000  153.000000        151.000000
# mean     0.408489    0.245324    0.123179    1.853072         75.209934
# std      0.150744    0.134395    0.102133    0.499490         12.962365
# ...

# %%
whc.sort_values(by='Happiness Rank',ascending=True).head(10)
# Out:
#        Country  Happiness Rank  Happiness Score   Economy    Family    Health  \
# 0       Norway               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3  Switzerland               4            7.494  1.564980  1.516912  0.858131
# 4      Finland               5            7.469  1.443572  1.540247  0.809158
# 5  Netherlands               6            7.377  1.503945  1.428939  0.810696
# 6       Canada               7            7.316  1.479204  1.481349  0.834558
# 7  New Zealand               8            7.314  1.405706  1.548195  0.816760
# 8       Sweden               9            7.284  1.494387  1.478162  0.830875
# 9    Australia              10            7.284  1.484415  1.510042  0.843887
#
#     Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# ...

# %%
whc.sort_values(by='Happiness Rank',ascending=False).head(10)
# Out:
#                       Country  Happiness Rank  Happiness Score   Economy  \
# 152  Central African Republic             155            2.693  0.000000
# 151                   Burundi             154            2.905  0.091623
# 150                  Tanzania             153            3.349  0.511136
# 149                     Syria             152            3.462  0.777153
# 148                    Rwanda             151            3.471  0.368746
# 147                      Togo             150            3.495  0.305445
# 146                    Guinea             149            3.507  0.244550
# 145                   Liberia             148            3.533  0.119042
# 144               South Sudan             147            3.591  0.397249
# 143                     Yemen             146            3.593  0.591683
#
#        Family    Health   Freedom  Generosity  Corruption  Dystopia  \
# 152  0.000000  0.018773  0.270842    0.280876    0.056565  2.066005
# ...

# %%
whc[whc['Happiness Score'] > 5].shape[0]
# Out:
# 96

# %%
whc[(whc['Happiness Score'] >4) & (whc['Region'] == 'Europe')].shape[0]
# Out:
# 1

# %%
whc[(whc['Happiness Score'] > 4) & (whc['Region'] == 'Africa')].shape[0]
# Out:
# 28

# %%
whc[(whc['Happiness Score'] > 6) & (whc['Region'] == 'Asia-Pacific')].shape[0]
# Out:
# 11

# %%
whc[(whc['Happiness Score'] > 6) & (whc['Region'] == 'Eastern Europe')].shape[0]
# Out:
# 1

# %%
whc[(whc['Happiness Score'] > 4) & (whc['Region'] == 'Latin America')].shape[0]
# Out:
# 21

# %%
whc[(whc['Happiness Score'] > 4) & (whc['Region'] == 'Western Europe')].shape[0]
# Out:
# 19

# %%
whc[(whc['Happiness Score'] > 4) & (whc['Region'] == 'North America')].shape[0]
# Out:
# 2

# %%
whc[['Economy', 'Family','Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia']].head(10).plot(kind='barh',
xticks=np.arange(9), stacked=True, figsize= (10, 10))

plt.xlabel("Happiness Score")
plt.title('Happiness Score of the top 10 Countries')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
whc['Happiness Score'].plot(kind='hist', bins=[0,1,2,3,4,5,6,7,8], figsize=(6,6))

plt.xlabel("Happiness Score in percent")
plt.title("Distribution of HHappiness Score")
# Out:
# Text(0.5, 1.0, 'Distribution of HHappiness Score')

# %%
whc['Job Satisfaction'].plot(kind='hist', bins=[ 40, 50, 60, 70, 80, 90, 100], figsize=(6,6))

plt.xlabel("Job Satisfaction in Percent")
plt.title("Distribution of Job Satisfaction")
# Out:
# Text(0.5, 1.0, 'Distribution of Job Satisfaction')

# %%
whc['Economy'].plot(kind='hist', bins=[0,1,2,3], figsize=(6,6))

plt.xlabel("Economy in percent")
plt.title("Distribution of Economy")
# Out:
# Text(0.5, 1.0, 'Distribution of Economy')

# %%
whc['Family'].plot(kind='hist', bins=[0,1,2,3], figsize=(6,6))

plt.xlabel("Family in percent")
plt.title("Distribution of Family")
# Out:
# Text(0.5, 1.0, 'Distribution of Family')

# %%
whc['Health'].plot(kind='hist', bins=[0,1,2,3], figsize=(6,6))

plt.xlabel("Health in percent")
plt.title("Distribution of Health")
# Out:
# Text(0.5, 1.0, 'Distribution of Health')

# %%
whc['Happiness Score'].plot(kind='hist', bins=[0,1,2,3,4,5,6,7,8], figsize=(6,6))

plt.xlabel("Health ")
plt.title("Distribution of Health")
# Out:
# Text(0.5, 1.0, 'Distribution of Health')

# %%
whc['Generosity'].plot(kind='hist', bins=[0,1,2], figsize=(6,6))

plt.xlabel("Generosity Score in percent")
plt.title("Distribution of Generosity")
# Out:
# Text(0.5, 1.0, 'Distribution of Generosity')

# %%
whc['Dystopia'].plot(kind='hist', bins=[0,1,2,3,4,5], figsize=(6,6))

plt.xlabel("Dystopia Score in percent")
plt.title("Distribution of Dystopia")
# Out:
# Text(0.5, 1.0, 'Distribution of Dystopia')

# %%
whc['Corruption'].plot(kind='hist', bins=[0,1,2], figsize=(6,6))

plt.xlabel("Corruption Score in percent")
plt.title("Distribution of Corruption")
# Out:
# Text(0.5, 1.0, 'Distribution of Corruption')

# %%
whc_Region = whc.groupby('Region')
whc_Region['Happiness Score'].describe().sort_values(by="mean",ascending=True).head(10)
# Out:
#                 count      mean       std    min      25%     50%      75%  \
# Region
# Europe            1.0  4.096000       NaN  4.096  4.09600  4.0960  4.09600
# Africa           44.0  4.239500  0.681866  2.693  3.78775  4.1850  4.60425
# Asia-Pacific     43.0  5.358326  0.955062  3.462  4.65000  5.2690  6.02750
# Eastern Europe   22.0  5.513091  0.397909  4.644  5.24750  5.5900  5.83475
# Latin America    22.0  5.957818  0.750925  3.603  5.54850  6.0395  6.45400
# Western Europe   19.0  6.880474  0.611070  5.195  6.56800  6.9510  7.42300
# North America     2.0  7.154500  0.228395  6.993  7.07375  7.1545  7.23525
#
#                   max
# Region
# Europe          4.096
# Africa          5.872
# Asia-Pacific    7.314
# Eastern Europe  6.098
# Latin America   7.079
# Western Europe  7.537
# North America   7.316

# %%
region_percent=whc.groupby('Region')
region=['Europe','Africa','Asia-Pacific','Eastern Europe','Latin America','Western Europe','North America']
count=[1,44,43,22,22,19,2]
plt.pie(count, labels=region,colors=['steelblue','turquoise','springgreen','lightskyblue','darkturquoise',
                                     'palegreen','lightseagreen'],autopct='%.2f%%')
plt.legend(iloc='center left')
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 6
#       3 count=[1,44,43,22,22,19,2]
#       4 plt.pie(count, labels=region,colors=['steelblue','turquoise','springgreen','lightskyblue','darkturquoise',
#       5                                      'palegreen','lightseagreen'],autopct='%.2f%%')
# ----> 6 plt.legend(iloc='center left')
#       7 plt.show
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3372, in legend(*args, **kwargs)
#    3370 @_copy_docstring_and_deprecators(Axes.legend)
#    3371 def legend(*args, **kwargs) -> Legend:
# -> 3372     return gca().legend(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:323, in Axes.legend(self, *args, **kwargs)
#     206 """
#     207 Place a legend on the Axes.
#     208
#    (...)
#     320 .. plot:: gallery/text_labels_and_annotations/legend.py
#     321 """
# ...

# %%
sb.countplot(x ='Region', data = whc)
plt.xticks(rotation = 60)
plt.show()

# %%
list_of_features = ['Economy','Family','Generosity','Corruption','Freedom']
sb.boxplot(data=whc.loc[:,list_of_features],orient='h',palette = 'Set2')
plt.show()

# %%
sb.swarmplot(x = "Region", y = "Generosity", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Generosity Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\3749748684.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Generosity", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Job Satisfaction", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Job Satisfaction Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\546345402.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Job Satisfaction", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Corruption", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Corruption Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\4123602917.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Corruption", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Freedom", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Freedom Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\694727149.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Freedom", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Health", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Health Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\586608628.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Health", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Family", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Family Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\1496037098.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Family", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Economy", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Economy Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\2532369404.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Economy", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Happiness Score", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Happiness Score Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\1500082213.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Happiness Score", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.swarmplot(x = "Region", y = "Happiness Rank", data = whc, palette="Set3")
plt.xticks(rotation = 90)
plt.title("Happiness Rank Distribution by Region in 2023")
plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_6604\1347366025.py:1: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sb.swarmplot(x = "Region", y = "Happiness Rank", data = whc, palette="Set3")
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sb.pairplot(data=whc, kind='reg', size = 6,
                  x_vars=['Happiness Score'],
                  y_vars=['Economy', 'Family','Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia'])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sb.pairplot(data=whc, size = 6, hue='Region',
                  x_vars=['Happiness Score'],
                  y_vars=['Economy', 'Family','Health', 'Freedom', 'Generosity', 'Corruption', 'Dystopia'])
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
